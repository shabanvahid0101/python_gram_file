# %%
import matplotlib.pyplot as plt

# %%
from skimage import data
from skimage.color import rgb2gray
from skimage import io

# %%
coin=data.coins()
io.imshow(coin)

# %%
img=io.imread("./aa.jpg")
io.imshow(img)

# %%
img.shape
# Out:
# (1472, 3264, 3)
